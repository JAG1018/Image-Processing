# %%
# !unzip /content/DiffMorph-master.zip

# %%
# !pip instal
# Out:
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
! pip install -r /home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/DiffMorph-master/requirements.txt
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/JAGGU/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install pymorphy2
# Out:
# ...
#   Using cached pymorphy2-0.9.1-py3-none-any.whl (55 kB)
# ...
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
# ...
#   Using cached DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=f8f89177c2a0851a568932dbe7dcdcb02b5e043781d48a71a982d943daadbf2c
#   Stored in directory: /home/hpc-lavasa/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built docopt
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/JAGGU/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install tensorflow-addons
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/JAGGU/bin/python3 -m pip install --upgrade pip' command.

# %%
# !python /home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/DiffMorph-master/morph.py -s /home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/Renamed_images/0.jpg -t /home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/Renamed_images/1.jpg
# Out:
# 2022-11-27 02:42:49.636267: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-27 02:42:50.686152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-27 02:42:50.702842: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-27 02:42:50.703018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
#  !python /content/DiffMorph-master/morph.py -s /content/DiffMorph-master/images/009_02.jpg -t /content/DiffMorph-master/images/025_02.jpg

# %%
! pip install tensorflow==2.9.1
! pip install tensorflow-addons==0.17.1
# Out:
# ...
#   Using cached tensorflow-2.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
# ...
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# ...
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/JAGGU/bin/python3 -m pip install --upgrade pip' command.
# ...

# %%
python_code_loc1 = '/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/DiffMorph-master/morph.py'
image_loc1 = '/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/Renamed_images'
output_loc1 = '/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/output_videos2'
img_1 = 1
img_2 = 2
img_1_name = '{}.jpg'.format(img_1)
img_2_name = '{}.jpg'.format(img_2)
video_name = 'morphed_{}_{}.mp4'.format(img_1, img_2)

# %%
# !python /home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/DiffMorph-master/morph.py -s /home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/Renamed_images/3.jpg -t /home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/Renamed_images/4.jpg
# Out:
# 2022-11-27 02:56:08.049383: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-27 02:56:08.857679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-27 02:56:08.871792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-27 02:56:08.871906: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# ! pip install tensorflow==2.8
# ! apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
import os

# %%
# for img_1 in [0, 1, 2, 3, 4, 5]:
#   for img_2 in [0, 1, 2, 3, 4, 5]:
#     if img_1 < img_2:
#       img_1_name = '{}.jpg'.format(img_1)
#       img_2_name = '{}.jpg'.format(img_2)
#       video_name = 'morphed_{}_{}.mp4'.format(img_1, img_2)

#       print("video_name " + video_name)
#       print("STARTED")

#       statement = 'python {} -s {}{} -t {}{} --output {}{}'.format(python_code_loc1, image_loc1, img_1_name, image_loc1, img_2_name, output_loc1, video_name)
#       os.system(statement)

#       print("FINISHED")
# Out:
# video_name morphed_0_1.mp4
# STARTED
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 11
#       8 print("video_name " + video_name)
#       9 print("STARTED")
# ---> 11 statement = 'python {} -s {}{} -t {}{} --output {}{}'.format(python_code_loc1, image_loc1, img_1_name, image_loc1, img_2_name, output_loc1, video_name)
#      12 os.system(statement)
#      14 print("FINISHED")
#
# NameError: name 'python_code_loc1' is not defined

# %%
image_list = [file for file in os.listdir('/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/Renamed_Images_2') if not file.startswith('.')]
image_list.sort()
epochs = 1000 #@param {type:"number"}
warp_scale = 0.05 #@param {type:"number"}
mult_scale = 0.4 #@param {type:"number"}
add_scale = 0.4 #@param {type:"number"}
add_first = False #@param {type:"boolean"}
filenames = []
for i in range(len(image_list) - 1):
    start = f'/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/Renamed_Images_2/{image_list[i]}'
    end = f'/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/Renamed_Images_2/{image_list[i+1]}'
    if add_first:
        # !python m/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/DiffMorph-master/morph.py -s $start -t $end -e $epochs -a $add_scale -m $mult_scale -w $warp_scale --add_first
    else:
        # !python /home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/DiffMorph-master/morph.py -s $start -t $end -e $epochs -a $add_scale -m $mult_scale -w $warp_scale
    filename = f'/home/hpc-lavasa/Desktop/Avastha_Research-20221126T174731Z-001/Avastha_Research/output_videos2/morph{i:03d}.mp4'
    filenames.append(filename)
    # !mv /content/DiffMorph/morph/morph.mp4 $filename
# Out:
# 2022-11-27 02:56:32.827371: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-27 02:56:33.701819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-27 02:56:33.716335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-27 02:56:33.716481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
